# %%
import base64
import vertexai
from vertexai.generative_models import GenerativeModel, Part, SafetySetting


def generate():
    vertexai.init(project="qwiklabs-gcp-02-60deb149183c", location="us-central1")
    model = GenerativeModel(
        "gemini-1.5-flash-002",
        system_instruction=[textsi_1]
    )
    responses = model.generate_content(
        [text1],
        generation_config=generation_config,
        safety_settings=safety_settings,
        stream=True,
    )

    for response in responses:
        print(response.text, end="")

text1 = """Emotional resonance (e.g., empowered, connected)

input: Write a tagline for a durable backpack designed for hikers that makes them feel prepared. Consider styles like minimalist.
output: Built for the Journey: Your Adventure Essentials.


input: Emotional resonance (e.g., empowered, connected)
output:

"""
textsi_1 = """Cymbal Direct is partnering with an outdoor gear retailer. They\'re launching a new line of products designed to encourage young people to explore the outdoors. Help them create catchy taglines for this product line."""

generation_config = {
    "max_output_tokens": 8192,
    "temperature": 2,
    "top_p": 0.98,
}

safety_settings = [
    SafetySetting(
        category=SafetySetting.HarmCategory.HARM_CATEGORY_HATE_SPEECH,
        threshold=SafetySetting.HarmBlockThreshold.OFF
    ),
    SafetySetting(
        category=SafetySetting.HarmCategory.HARM_CATEGORY_DANGEROUS_CONTENT,
        threshold=SafetySetting.HarmBlockThreshold.OFF
    ),
    SafetySetting(
        category=SafetySetting.HarmCategory.HARM_CATEGORY_SEXUALLY_EXPLICIT,
        threshold=SafetySetting.HarmBlockThreshold.OFF
    ),
    SafetySetting(
        category=SafetySetting.HarmCategory.HARM_CATEGORY_HARASSMENT,
        threshold=SafetySetting.HarmBlockThreshold.OFF
    ),
]

generate()
# Out:
# Here are some taglines for Cymbal Direct's new outdoor gear line, targeting young people, categorized by the feeling they evoke:
#
# **Focusing on Adventure & Exploration:**
#
# * **Unfold Your Adventure.** (Simple, versatile)
# * **Find Your Wild.** (Evocative, emphasizes discovery)
# * **Explore. Discover. Create.** (Action-oriented, inspiring)
# * **Gear Up. Get Out. Grow.** (Highlights personal development)
# * **Your Next Adventure Starts Here.** (Direct, inviting)
# * **Beyond the Trail. Beyond Yourself.** (Ambitious, aspirational)
#
# **Emphasizing Empowerment & Confidence:**
#
# * **Own Your Outdoors.** (Confident, empowering)
# * **Adventure Awaits. You're Ready.** (Reassuring, empowering)
# * **Unleash Your Inner Explorer.** (Focuses on inner strength)
# * **Gear Designed for Your Strength.** (Highlights durability & the user)
# * **Empower Your Journey.** (Directly focuses on empowerment)
#
# **Highlighting Connection with Nature:**
#
# * **Connect With Nature. Connect With Yourself.** (Inner peace and nature connection)
# * **Find Your Roots. Find Your Adventure.** (Nature and personal growth)
# * **Nature's Calling. Answer it.** (Action-oriented, captivating)
# * **Respect the Wild. Explore It Wisely.** (Sustainability conscious and action-orientated)
#
#
# **Catchy & Playful:**
#
# * **Get Your Wild On.** (Energetic, fun)
# * **Adventure Proof.** (Simple, memorable)
# * **Made for Wonder.** (Positive, aspirational)
# * **Escape the Ordinary.** (Enticing, suggests escape)
#
#
# **Taglines emphasizing specific product types (examples):**
#
# * **(For Backpacks):**  Carry Your Dreams.
# * **(For Hiking Boots):**  Find Your Foothold.
# * **(For Camping Gear):** Sleep Under the Stars.  Shine Brighter.
# * **(For Hydration packs):** Adventure's Thirst Quencher.
#
# When selecting a tagline, consider the overall brand identity and target audience.  Test different options to see which resonates most strongly.

# %%
from vertexai.preview.generative_models import GenerativeModel

model = GenerativeModel("gemini-1.5-pro")

prompt = """
Cymbal Direct is partnering with an outdoor gear retailer. They\'re launching a new line of products designed to encourage young people to explore the outdoors. Help them create catchy taglines for this product line.

input: Write a tagline for a durable backpack designed for hikers that makes them feel prepared. Consider styles like minimalist.
output: Built for the Journey: Your Adventure Essentials.

input: Write a tagline for a durable backpack designed for hikers that makes them feel prepared. Consider styles like minimalist.
output: Built for the Journey: Your Adventure Essentials.

input: Emotional resonance (e.g., empowered, connected)
output:
"""

responses = model.generate_content(
    prompt,
    generation_config={
        "temperature": 1,
        "max_output_tokens": 2048,
        "top_p": 1.0,
        "top_k": 40,
    },
    stream=True
    )

for response in responses:
    print(response.text)
# Out:
# Here
#  are some taglines for a durable backpack designed for hikers, focusing on emotional resonance
# :
#
# **Empowerment:**
#
# * **Carry Confidence:** Every trail
# , your way.
# * **Your Adventure, Your Pack, Your Terms.**
# * **Go Further, Feel Stronger.**
# * **Equipped to Explore:
#  Unleash Your Inner Adventurer.**
#
# **Connection:**
#
# * **Connecting You to the Wild:** One adventure at a time.
# * **Find Your Path
# , Pack Your Passion.**
# * **Shared Trails, Shared Stories, Shared Strength.**
# * **Embrace the Journey, Connect with Nature.**
#
# **Hope these inspire you! Let me know if you have other tagline ideas you'd
#  like me to explore!**
