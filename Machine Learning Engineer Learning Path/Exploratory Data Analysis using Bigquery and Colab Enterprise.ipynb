# %%
    import numpy as np
    from matplotlib import pyplot as plt

    ys = 200 + np.random.randn(100)
    x = [x for x in range(len(ys))]

    plt.plot(x, ys, '-')
    plt.fill_between(x, ys, 195, where=(ys > 195), facecolor='g', alpha=0.6)

    plt.title("Colab Enterprise")
    plt.show()

# %%
import seaborn as sns
import pandas as pd
import numpy as np
from google.cloud import bigquery
bq = bigquery.Client()

# %% [markdown]
# Import BigQuery Client

# %%
client = bigquery.Client()

query = """SELECT * FROM `bigquery-public-data.catalonian_mobile_coverage_eu.mobile_data_2015_2017` LIMIT 1000"""
job = client.query(query)
df = job.to_dataframe()

# %% [markdown]
# Download a BigQuery Table into a Pandas Dataframe

# %%
# %%bigquery df
# SELECT *
# FROM `bigquery-public-data.catalonian_mobile_coverage_eu.mobile_data_2015_2017`
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |

# %%
# Show the first five rows of the Pandas Dataframe
df.head()
# Out:
#          date      hour       lat     long  signal  network  operator  status  \
# 0  2017-06-18  11:02:22  41.82760  1.89417      14   orange  MASMOVIL       2
# 1  2017-08-28  18:40:08  41.18712  1.56905      10  LlamaYA   LlamaYA       0
# 2  2015-01-31  20:10:37  41.60843  2.14638       4     null      null       2
# 3  2017-02-28  15:10:11  41.19566  1.59217      13  LlamaYA   LlamaYA       2
# 4  2017-02-28  11:58:04  41.11581  1.25267      19   orange  MASMOVIL       2
#
#             description   net  speed  satellites  precission provider  \
# 0  STATE_EMERGENCY_ONLY    4G    2.9         9.0        17.0      gps
# 1      STATE_IN_SERVICE  None    0.0         0.0        18.0    fused
# 2  STATE_EMERGENCY_ONLY    3G   14.2         0.0        48.0      gps
# 3  STATE_EMERGENCY_ONLY    3G    2.8         9.0         8.0      gps
# 4  STATE_EMERGENCY_ONLY    4G    3.3         3.0        13.0      gps
#
#      activity  downloadSpeed  uploadSpeed postal_code  town_name  \
# 0     ON_FOOT            NaN          NaN      081918    Sallent
# 1       STILL            NaN          NaN      430379   Calafell
# 2     TILTING            NaN          NaN      082671  Sentmenat
# 3  ON_BICYCLE            NaN          NaN      430379   Calafell
# 4     ON_FOOT            NaN          NaN      431482  Tarragona
#
#              position_geom
# 0   POINT(1.89417 41.8276)
# 1  POINT(1.56905 41.18712)
# 2  POINT(2.14638 41.60843)
# 3  POINT(1.59217 41.19566)
# 4  POINT(1.25267 41.11581)

# %%
# Get information on the Pandas Dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11744914 entries, 0 to 11744913
# Data columns (total 20 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   date           dbdate
#  1   hour           dbtime
#  2   lat            float64
#  3   long           float64
#  4   signal         Int64
#  5   network        object
#  6   operator       object
#  7   status         Int64
#  8   description    object
#  9   net            object
#  10  speed          float64
#  11  satellites     float64
#  12  precission     float64
#  13  provider       object
#  14  activity       object
#  15  downloadSpeed  float64
#  16  uploadSpeed    float64
#  17  postal_code    object
#  18  town_name      object
#  19  position_geom  object
# dtypes: Int64(2), dbdate(1), dbtime(1), float64(7), object(9)
# memory usage: 1.8+ GB

# %%
# Get statistics on the Pandas Dataframe
df.describe()
# Out:
#                 lat          long      signal      status         speed  \
# count  1.174491e+07  1.174491e+07  11744914.0  11744914.0  1.174491e+07
# mean   4.120760e+01  7.851310e-01   13.262954    1.778794  2.643376e+01
# std    3.481886e+00  9.397493e+00    7.467304    0.633283  3.553885e+01
# min   -7.703775e+01 -1.787292e+02         0.0         0.0  0.000000e+00
# 25%    4.138028e+01  1.690790e+00         8.0         2.0  1.400000e+00
# 50%    4.148911e+01  2.123840e+00        13.0         2.0  7.400000e+00
# 75%    4.169777e+01  2.245140e+00        18.0         2.0  4.080000e+01
# max    6.343513e+01  1.396410e+02        99.0         3.0  2.550000e+02
#
#          satellites    precission  downloadSpeed  uploadSpeed
# count  1.174369e+07  1.174369e+07            0.0          0.0
# mean   9.795352e+05  4.636630e+07            NaN          NaN
# std    3.356759e+09  9.644288e+10            NaN          NaN
# min    0.000000e+00  0.000000e+00            NaN          NaN
# 25%    2.000000e+00  1.000000e+01            NaN          NaN
# 50%    5.000000e+00  1.700000e+01            NaN          NaN
# 75%    7.000000e+00  3.000000e+01            NaN          NaN
# max    1.150330e+13  2.415039e+14            NaN          NaN

# %%
# Plot a correlation using Seaborn.
numeric_df = df.select_dtypes(include=[np.number])

corr_matrix = numeric_df.corr()

plt.figure(figsize=(10, 5))
sns.heatmap(corr_matrix, annot=True, vmin=0, vmax=1, cmap='viridis')
plt.show()

# %% [markdown]
# Write a SQL query to pick up specific fields from a BigQuery dataset

# %%
# %%bigquery df2
# SELECT signal, status
# FROM `bigquery-public-data.catalonian_mobile_coverage_eu.mobile_data_2015_2017`
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |

# %%
# Get the first five rows of the new fields.
df2.head()
# Out:
#    signal  status
# 0      52       2
# 1      55       2
# 2      35       2
# 3      63       2
# 4      61       2
